# %% [markdown]
# <div style="direction:rtl;line-height:300%; font-family: Yas">
#     <font face="XB Zar" size=5>
#         <div style="direction:rtl;line-height:300%; font-family: Yas">
#             <font   size=5>
#                 <div align=center>
#                     <font  size=۲۰>
#                         <p></p>
#                             درس آنالیز داده ها
#                     </font>
#                     <br>
#                     <font>
#                         دانشگاه صنعتی شریف - دانشکده مهندسی برق
#                     </font>
#                     <br>
#                     <font color=blue>
#                         تمرین هشتم
#                     </font>
#                     <br>
#                      ۱۳۹۹
#                 </div>
#             </font>
#         </div>
#     </font>
# </div>

# %% [markdown]
# ## Name : Reza Ramezanpour
# ## Student ID: 95101558

# %% [markdown]
# # Loading Packages

# %%
# import packages
from pyspark.ml.classification import LogisticRegression
from pyspark.mllib.evaluation import RegressionMetrics
from pyspark.ml.feature import StandardScaler,VectorAssembler
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml import Pipeline
from pyspark import SparkContext
import pyspark
from pyspark.sql import *
from pyspark.sql.functions import *
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Load Train Data

# %%
# File location and type
file_location = "file:/databricks/driver/mnist_train.csv"
file_type = "csv"

# CSV options
infer_schema = "True"
first_row_is_header = "True"
delimiter = ","

col_name = ["label"] + ['pixel'+str(i) for i in range(784)]
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location) \
  .toDF(*col_name)

display(df.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Build Model

# %%
# pack features
vectorizer = VectorAssembler(inputCols=['pixel'+str(i) for i in range(784)], outputCol="pack_features")

# use standard scaler to scale data between [-1,1]
standardizer = StandardScaler(inputCol=vectorizer.getOutputCol(), outputCol="features",withStd=True, withMean=True)

# using logistic regression
svm = LogisticRegression()

# parameter should be consider for tuning
#0.01, 0.1, 1, 10
paramGrid = ParamGridBuilder().addGrid(svm.regParam, [0.1]).build()

# stages of operations
pipeline = Pipeline(stages=[vectorizer, standardizer, svm])

# using 5 fold cross validation
crossval = CrossValidator(estimator=pipeline, estimatorParamMaps=paramGrid, evaluator=MulticlassClassificationEvaluator(), numFolds=5)

# fit on training data
cvModel = crossval.fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Best Model Validation Accuracy

# %%
bM.accuracy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 0.9041817363622727</div>

# %% [markdown]
# # Loading Test

# %%
# File location and type
file_location = "/FileStore/tables/mnist_test.csv"
file_type = "csv"

# CSV options
infer_schema = "True"
first_row_is_header = "True"
delimiter = ","

col_name = ["label"] + ['pixel'+str(i) for i in range(784)]
# The applied options are for CSV files. For other file types, these will be ignored.
test_df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location) \
  .toDF(*col_name)

display(test_df.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Use best Model to predict Test

# %%
test_pred = cvModel.transform(test_df).select("label", "prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Evaluate on Test

# %%
# using multicalss evaluator
multi_eval = MulticlassClassificationEvaluator()
multi_eval.setLabelCol('label')
multi_eval.setPredictionCol("prediction")

# test accuracy
multi_eval.evaluate(test_pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 0.9073079592884996</div>
